# %% [markdown]
# ## Red wine quality and deployment by Prachi Pathare

# %% [markdown]
# ## Statsly analytics internship

# %%
# libraries
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
wine = pd.read_csv("Red Wine Quality.csv")

# %%
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
wine.shape
# Out:
# (1599, 12)

# %% [markdown]
# * wine.shape gives the size of the data frame (no. of rows, no. columns)

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# * wine.head only gives first five rows

# %%
wine.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# ...

# %% [markdown]
# * wine.tail gives last five rows

# %%
wine[499:501]
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 499            8.7              0.69         0.31             3.0      0.086
# 500            7.8              0.52         0.25             1.9      0.081
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 499                 23.0                  81.0   1.0002  3.48       0.74
# 500                 14.0                  38.0   0.9984  3.43       0.65
#
#      alcohol  quality
# 499     11.6        6
# 500      9.0        6

# %%
wine[100:120]
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 100            8.3             0.610         0.30             2.1      0.084
# 101            7.8             0.500         0.30             1.9      0.075
# 102            8.1             0.545         0.18             1.9      0.080
# 103            8.1             0.575         0.22             2.1      0.077
# 104            7.2             0.490         0.24             2.2      0.070
# 105            8.1             0.575         0.22             2.1      0.077
# 106            7.8             0.410         0.68             1.7      0.467
# 107            6.2             0.630         0.31             1.7      0.088
# 108            8.0             0.330         0.53             2.5      0.091
# 109            8.1             0.785         0.52             2.0      0.122
# 110            7.8             0.560         0.19             1.8      0.104
# ...

# %%
wine[:40]
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# 5             7.4             0.660         0.00             1.8      0.075
# 6             7.9             0.600         0.06             1.6      0.069
# 7             7.3             0.650         0.00             1.2      0.065
# 8             7.8             0.580         0.02             2.0      0.073
# 9             7.5             0.500         0.36             6.1      0.071
# 10            6.7             0.580         0.08             1.8      0.097
# ...

# %%
wine[40:]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 40              7.3             0.450         0.36             5.9      0.074
# 41              8.8             0.610         0.30             2.8      0.088
# 42              7.5             0.490         0.20             2.6      0.332
# 43              8.1             0.660         0.22             2.2      0.069
# 44              6.8             0.670         0.02             1.8      0.050
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# * wine[x:y] means x is the starting value and y is the ending value

# %%
wine.dtypes  #.dtypes shows the type of each columns.
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
wine.info() # .info gives the information abt data frame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
wine.describe().T
# Out:
#                        count       mean        std      min      25%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# citric acid           1599.0   0.270976   0.194801  0.00000   0.0900
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.9000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1599.0   3.311113   0.154386  2.74000   3.2100
# sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# quality               1599.0   5.636023   0.807569  3.00000   5.0000
#
#                            50%        75%        max
# ...

# %% [markdown]
# * Density has a normal distribution with standard deviation 0 we may drop this column.

# %%
wine.nunique() # gives the count of unique value in each columns
# Out:
# fixed acidity            96
# volatile acidity        143
# citric acid              80
# residual sugar           91
# chlorides               153
# free sulfur dioxide      60
# total sulfur dioxide    144
# density                 436
# pH                       89
# sulphates                96
# alcohol                  65
# quality                   6
# dtype: int64

# %%
wine.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
wine.duplicated().sum()
# Out:
# 240

# %% [markdown]
# * it gives the number of duplicate rows in data set
# * we have to drop these duplicate rows.

# %% [markdown]
# # univariant analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
wine.hist(bins = 25, figsize = (18,10))
plt.show()

# %% [markdown]
# * 1.Density and pH, chlorides seems  normally distributed
# * 2.free sulfur, total sulfur are still skewed
# * 3.citric acid seem to hace large number of zero values
# * 4.alcohol is still skewed
# * 5.volatile acidity and fixed acidity is fairly normalized

# %%
fig, ax = plt.subplots(ncols = 6, nrows = 2, figsize = (20,10))
index = 0
ax = ax.flatten()

for col, value in wine.items():
    if col != 'type':
        sns.boxplot(y = col, data = wine, ax = ax[index])
        index += 1
plt.tight_layout(pad = 0.5, w_pad = 0.7, h_pad = 5.0)

# %%
sns.countplot(wine['quality'])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %% [markdown]
# * The data is fairly balanced for target variable

# %%
plt.figure(figsize = (18,6))
wine.boxplot()
# Out:
# <AxesSubplot:>

# %%
wine['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %% [markdown]
# # bivariant analysis

# %%
sns.barplot(wine['quality'], wine['fixed acidity'])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='fixed acidity'>

# %%
plt.figure(figsize = (18,6))
sns.boxplot(wine['quality'], wine['fixed acidity'])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='fixed acidity'>

# %% [markdown]
# * you can see the fixed acidity for differnt quality of wine is not much away from median
# * it mean it have little correlation with quality

# %%
plt.figure(figsize = (18,6))
sns.boxplot(wine['quality'], wine['volatile acidity'])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='volatile acidity'>

# %% [markdown]
# *from the graph we can see that volatile acidity is for different wine quality
# *is significantly away from median trend shows it has strong negative correlations

# %%
plt.figure(figsize = (18,6))
sns.boxplot(wine['quality'], wine['citric acid'])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='citric acid'>

# %%
* Citric acid seems to have a positive correlation with Wine Quality
* Better wines have higher Citric Acid

# %%
plt.figure(figsize = (18,6))
sns.boxplot(wine['quality'], wine['residual sugar'])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='residual sugar'>

# %% [markdown]
# * residual sugar for differnt qualities of wine is almost not changing
# * higher quality of wine have little bit of more residual sugar

# %%
plt.figure(figsize = (18,6))
sns.boxplot(wine['quality'], wine['chlorides'])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='chlorides'>

# %% [markdown]
# * still chlorides are not much different from median but
# * low quality of wine have high % of chlorides

# %%
plt.figure(figsize = (18,6))
sns.boxplot(wine['quality'], wine['free sulfur dioxide'])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='free sulfur dioxide'>

# %% [markdown]
# * almost have no effect but high conc. of free so2 gives good quality of wine
# * and data is mostly distributed around wine quality of 5 and 6 so we have consider this variable.

# %%
plt.figure(figsize = (18,6))
sns.boxplot(wine['quality'], wine['total sulfur dioxide'])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='total sulfur dioxide'>

# %% [markdown]
# * same as free sulfur dioxide

# %%
plt.figure(figsize = (18,6))
sns.boxplot(wine['quality'], wine['density'])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='density'>

# %%
plt.figure(figsize = (18,6))
sns.boxplot(wine['quality'], wine['pH'])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='pH'>

# %%
plt.figure(figsize = (18,6))
sns.boxplot(wine['quality'], wine['sulphates'])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='sulphates'>

# %% [markdown]
# * High quality wines have significant sulphates level.

# %%
plt.figure(figsize = (18,6))
sns.boxplot(wine['quality'], wine['alcohol'])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='alcohol'>

# %% [markdown]
# * much variation of alcohol % for differnt quality of wine

# %% [markdown]
# # multivariant

# %%
plt.figure(figsize = (20,20))
sns.scatterplot(wine['fixed acidity'], wine['alcohol'], hue = wine['quality'])
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='alcohol'>

# %%
wine['quality'] = wine['quality'].map({3 : 'bad', 4 :'bad', 5: 'bad',
                                      6: 'good', 7: 'good', 8: 'good'})

# %%
wine['quality'].value_counts()
# Out:
# good    855
# bad     744
# Name: quality, dtype: int64

# %%
plt.figure(figsize = (18,6))
sns.scatterplot(wine['volatile acidity'], wine['alcohol'], hue = wine['quality'])
# Out:
# <AxesSubplot:xlabel='volatile acidity', ylabel='alcohol'>

# %%
plt.figure(figsize = (18,6))
sns.scatterplot(wine['citric acid'], wine['alcohol'], hue = wine['quality'])
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='alcohol'>

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

wine['quality'] = le.fit_transform(wine['quality'])

# %%
wine['quality'].value_counts()
# Out:
# 1    855
# 0    744
# Name: quality, dtype: int64

# %% [markdown]
# # correlation and heat map

# %%
plt.figure(figsize = (20,8))
plt.title('Correlation of all the Columns', fontsize = 20)
sns.heatmap(wine.corr(), annot = True, vmin = -1, vmax = 1, center = 0, fmt = '.1g', linewidths = 1, linecolor = 'white', 
            square = True, cmap ='RdBu')
# Out:
# <AxesSubplot:title={'center':'Correlation of all the Columns'}>

# %% [markdown]
# * 2 or more col have same corrlation with target variable we choose only one col for modelling

# %% [markdown]
# # Modelling

# %%
X = wine.drop('quality', axis = 1)
y = wine['quality']

# %% [markdown]
# * x is independent variable
# * y is dependent variable or target variable

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 1594    0
# 1595    1
# 1596    1
# 1597    0
# 1598    1
# Name: quality, Length: 1599, dtype: int32

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (1119, 11)
# (1119,)
# (480, 11)
# (480,)

# %%
x_train.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 925             8.6              0.22         0.36             1.9      0.064
# 363            12.5              0.46         0.63             2.0      0.071
# 906             7.2              0.54         0.27             2.6      0.084
# 426             6.4              0.67         0.08             2.1      0.045
# 1251            7.5              0.58         0.14             2.2      0.077
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 925                  53.0                  77.0  0.99604  3.47       0.87
# 363                   6.0                  15.0  0.99880  2.99       0.87
# 906                  12.0                  78.0  0.99640  3.39       0.71
# 426                  19.0                  48.0  0.99490  3.49       0.49
# 1251                 27.0                  60.0  0.99630  3.28       0.59
#
#       alcohol
# 925      11.0
# 363      10.2
# ...

# %%
x_test.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 803             7.7              0.56         0.08            2.50      0.114
# 124             7.8              0.50         0.17            1.60      0.082
# 350            10.7              0.67         0.22            2.70      0.107
# 682             8.5              0.46         0.31            2.25      0.078
# 1326            6.7              0.46         0.24            1.70      0.077
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 803                  14.0                  46.0   0.9971  3.24       0.66
# 124                  21.0                 102.0   0.9960  3.39       0.48
# 350                  17.0                  34.0   1.0004  3.28       0.98
# 682                  32.0                  58.0   0.9980  3.33       0.54
# 1326                 18.0                  34.0   0.9948  3.39       0.60
#
#       alcohol
# 803       9.6
# 124       9.5
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %%
x_train
# Out:
# array([[ 1.69536131e-01, -1.72107140e+00,  4.59303345e-01, ...,
#          1.01180685e+00,  1.22661179e+00,  5.50057013e-01],
#        [ 2.44606730e+00, -4.01957443e-01,  1.84105501e+00, ...,
#         -2.10687612e+00,  1.22661179e+00, -2.05174641e-01],
#        [-6.47680186e-01,  3.77472102e-02, -1.28054303e-03, ...,
#          4.92026353e-01,  2.97270776e-01,  5.50057013e-01],
#        ...,
#        [-6.47680186e-01,  4.77451864e-01, -1.07597628e+00, ...,
#          1.27169710e+00, -6.90154049e-01, -8.66002338e-01],
#        [-2.39072027e-01, -1.83099757e+00,  4.08127357e-01, ...,
#          3.72184202e-02,  8.20025095e-01,  1.39969262e+00],
#        [-1.46489650e+00, -1.33632983e+00, -5.24565306e-02, ...,
#          4.92026353e-01, -6.90154049e-01,  2.91015593e+00]])

# %% [markdown]
# * We tried different model among which we choose random forest model for deployment

# %% [markdown]
# # logistic regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import GridSearchCV, cross_val_score

lr = LogisticRegression()
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
# predicting the results for the test set
y_pred_train = lr.predict(x_train)
y_pred_test  = lr.predict(x_test)

print("Training accuracy :", accuracy_score(y_pred_train, y_train))
print("Testing accuracy  :", accuracy_score(y_pred_test, y_test))
# Out:
# Training accuracy : 0.7605004468275246
# Testing accuracy  : 0.7229166666666667

# %%
cm_test = confusion_matrix(y_test, y_pred_test)
print(cm_test)
# Out:
# [[161  52]
#  [ 81 186]]

# %%
print('Classification report for train data is : \n',
      classification_report(y_train, y_pred_train))

print('\n')
print('Classification report for test data is : \n',
      classification_report(y_test, y_pred_test))
# Out:
# Classification report for train data is :
#                precision    recall  f1-score   support
#
#            0       0.74      0.76      0.75       531
#            1       0.78      0.77      0.77       588
#
#     accuracy                           0.76      1119
#    macro avg       0.76      0.76      0.76      1119
# weighted avg       0.76      0.76      0.76      1119
#
#
#
# Classification report for test data is :
#                precision    recall  f1-score   support
#
#            0       0.67      0.76      0.71       213
#            1       0.78      0.70      0.74       267
#
#     accuracy                           0.72       480
#    macro avg       0.72      0.73      0.72       480
# weighted avg       0.73      0.72      0.72       480

# %%
import numpy as np
from sklearn import metrics
print('Error rate for Train Data is : \n',)
print('Mean Square Error (MSE)       :', metrics.mean_squared_error(y_train, y_pred_train))
print('Mean Absolute Error           :', metrics.mean_absolute_error(y_train, y_pred_train))
print('Root mean Square Error (RMSE) :', np.sqrt(metrics.mean_squared_error(y_train, y_pred_train)))
print('\n')
print('Error rate for Test Data is : \n',)
print('Mean Square Error (MSE)       :', metrics.mean_squared_error(y_test, y_pred_test))
print('Mean Absolute Error           :', metrics.mean_absolute_error(y_test, y_pred_test))
print('Root mean Square Error (RMSE) :', np.sqrt(metrics.mean_squared_error(y_test, y_pred_test)))
# Out:
# Error rate for Train Data is :
#
# Mean Square Error (MSE)       : 0.23949955317247543
# Mean Absolute Error           : 0.23949955317247543
# Root mean Square Error (RMSE) : 0.489386915612254
#
#
# Error rate for Test Data is :
#
# Mean Square Error (MSE)       : 0.27708333333333335
# Mean Absolute Error           : 0.27708333333333335
# Root mean Square Error (RMSE) : 0.5263870565784585

# %%
from sklearn.metrics import roc_curve
FPR_lr_train, TPR_lr_train, Thresholds_train = roc_curve(y_train, lr.predict_proba(x_train)[:,1])
FPR_lr_test, TPR_lr_test, Thresholds_test = roc_curve(y_test, lr.predict_proba(x_test)[:,1])
from sklearn.metrics import roc_curve

sns.set_style("whitegrid")
plt.figure(figsize = (20,8))

plt.plot(FPR_lr_train, TPR_lr_train, label = 'Train AUR Curve')
plt.plot(FPR_lr_test, TPR_lr_test,   label = 'Test AUR Curve')
# Plot Base Rate ROC
plt.plot([0,1], [0,1], label = 'Base Rate')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize = 20)
plt.ylabel('True Positive Rate',  fontsize = 20)
plt.title('ROC Graph', fontsize = 20)
plt.legend(loc = "lower right")
plt.show()

# %% [markdown]
# # decision tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()
dtc.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_dtc_train = dtc.predict(x_train)
y_pred_dtc_test  = dtc.predict(x_test)

print("Training accuracy :", accuracy_score(y_pred_dtc_train, y_train))
print("Testing accuracy  :", accuracy_score(y_pred_dtc_test, y_test))
# Out:
# Training accuracy : 1.0
# Testing accuracy  : 0.7291666666666666

# %%
* Decision tree is over fitted we are skipping it to check on test data.

# %% [markdown]
# # Random forest classsifier

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_rfc_train = rfc.predict(x_train)
y_pred_rfc_test  = rfc.predict(x_test)

print("Training accuracy :", accuracy_score(y_pred_rfc_train, y_train))
print("Testing accuracy  :", accuracy_score(y_pred_rfc_test, y_test))
# Out:
# Training accuracy : 1.0
# Testing accuracy  : 0.7854166666666667

# %% [markdown]
# # KNN classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

for i in range(1,4):
        neigh = KNeighborsClassifier(n_neighbors = i)
neigh.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred_knn_train = neigh.predict(x_train)
y_pred_knn_test  = neigh.predict(x_test)

print("Train Accuracy : ", accuracy_score(y_pred_knn_train, y_train))
print("Test Accuracy  : ", accuracy_score(y_pred_knn_test, y_test))
# Out:
# Train Accuracy :  0.8552278820375335
# Test Accuracy  :  0.7166666666666667

# %% [markdown]
# # Gaussian NB

# %%
from sklearn.naive_bayes import GaussianNB
clf = GaussianNB()
clf.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred_gnb_train = clf.predict(x_train)
y_pred_gnb_test  = clf.predict(x_test)

print("Train Accuracy : ", accuracy_score(y_pred_gnb_train, y_train))
print("Test Accuracy  : ", accuracy_score(y_pred_gnb_test, y_test))
# Out:
# Train Accuracy :  0.7327971403038427
# Test Accuracy  :  0.7375

# %% [markdown]
# # XG Boost classifier

# %%
from xgboost import XGBClassifier
gbm = XGBClassifier()
gbm.fit(x_train, y_train)
# Out:
# [10:25:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=8,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
y_pred_xgb_train = gbm.predict(x_train)
y_pred_xgb_test  = gbm.predict(x_test)

print("Train Accuracy : ", accuracy_score(y_pred_xgb_train, y_train))
print("Test Accuracy  : ", accuracy_score(y_pred_xgb_test, y_test))
# Out:
# Train Accuracy :  1.0
# Test Accuracy  :  0.8

# %% [markdown]
# # Hyper parameter tunning

# %% [markdown]
# # logistic regression (hyper parameter Tunning)

# %%
logreg = LogisticRegression()
params = {'C':[0.0001, 0.001, 0.01, 0.1, 1], 
          'class_weight': [{1:0.5, 0:0.5}, {1:0.4, 0:0.6},{1:0.6, 0:0.4}, {1:0.7, 0:0.3},{1:0.3, 0:0.7}], 
          'penalty': ['l1', 'l2'], 
          'solver': ['liblinear', 'saga'], 
          'max_iter':[50,100,150,200] 
         }
log_grid = GridSearchCV(estimator = logreg, 
                        param_grid = params, 
                        scoring = 'accuracy', 
                        cv = 5, 
                        n_jobs = -1)

log_grid.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'C': [0.0001, 0.001, 0.01, 0.1, 1],
#                          'class_weight': [{0: 0.5, 1: 0.5}, {0: 0.6, 1: 0.4},
#                                           {0: 0.4, 1: 0.6}, {0: 0.3, 1: 0.7},
#                                           {0: 0.7, 1: 0.3}],
#                          'max_iter': [50, 100, 150, 200],
#                          'penalty': ['l1', 'l2'],
#                          'solver': ['liblinear', 'saga']},
#              scoring='accuracy')

# %%
print("Best parameters for the model :", log_grid.best_params_)
print("Best score for the model      :", log_grid.best_score_)
# Out:
# Best parameters for the model : {'C': 1, 'class_weight': {1: 0.5, 0: 0.5}, 'max_iter': 50, 'penalty': 'l1', 'solver': 'liblinear'}
# Best score for the model      : 0.7525344330557335

# %%
logreg = LogisticRegression()
params = {'C':[0.0001, 0.001, 0.01, 0.1], 
          'class_weight': [ {1:0.4, 0:0.6},{1:0.6, 0:0.4}, {1:0.7, 0:0.3},{1:0.3, 0:0.7}], 
          'penalty': ['l1', 'l2'], 
          'solver': ['liblinear', 'saga'], 
          'max_iter':[100,150,200] 
         }
log_grid = GridSearchCV(estimator = logreg, 
                        param_grid = params, 
                        scoring = 'accuracy', 
                        cv = 11, 
                        n_jobs = -1)

log_grid.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=11, estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'C': [0.0001, 0.001, 0.01, 0.1],
#                          'class_weight': [{0: 0.6, 1: 0.4}, {0: 0.4, 1: 0.6},
#                                           {0: 0.3, 1: 0.7}, {0: 0.7, 1: 0.3}],
#                          'max_iter': [100, 150, 200], 'penalty': ['l1', 'l2'],
#                          'solver': ['liblinear', 'saga']},
#              scoring='accuracy')

# %%
print("Best parameters for the model :", log_grid.best_params_)
print("Best score for the model      :", log_grid.best_score_)
# Out:
# Best parameters for the model : {'C': 0.1, 'class_weight': {1: 0.4, 0: 0.6}, 'max_iter': 100, 'penalty': 'l2', 'solver': 'liblinear'}
# Best score for the model      : 0.7365471841301777

# %%
y_probabilities = log_grid.predict_proba(x_test)[:,1]

#Create true and false positive rates
false_positive_rate_log, true_positive_rate_log, threshold_log = roc_curve(y_test, y_probabilities)
#Plot ROC Curve
plt.figure(figsize = (20,8))
plt.title('Revceiver Operating Characterstic')
plt.plot(false_positive_rate_log, true_positive_rate_log, linewidth = 2)
plt.plot([0,1], ls='--', linewidth = 2)
plt.plot([0,0], [1,0], c = '.5', linewidth = 2)
plt.plot([1,1], c = '.5', linewidth = 2)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.show()

# %%
from sklearn.metrics import roc_auc_score
print("area under the curve :", roc_auc_score(y_test, y_probabilities))
# Out:
# area under the curve : 0.7995463417207365

# %% [markdown]
# # random forest classifier (hyper parameter tunning)

# %%
params = {
    'n_estimators':[500,750,1000], 
    'max_depth': [80,90,100], 
    'min_samples_leaf': [1, 2, 3], 
    'criterion': ["gini", "entropy"] 
}
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
model = RandomForestClassifier(random_state = 42)
grid_search = GridSearchCV(estimator = model, 
                           param_grid = params, 
                           cv = 5, n_jobs = -1, verbose = 1, scoring = "accuracy")
grid_search.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [80, 90, 100],
#                          'min_samples_leaf': [1, 2, 3],
#                          'n_estimators': [500, 750, 1000]},
#              scoring='accuracy', verbose=1)

# %%
print("Best parameters for the model :", grid_search.best_params_)
print("Best score for the model      :", grid_search.best_score_)
# Out:
# Best parameters for the model : {'criterion': 'gini', 'max_depth': 80, 'min_samples_leaf': 1, 'n_estimators': 750}
# Best score for the model      : 0.8061338885329917

# %%
test_rfc_pred  = grid_search.predict(x_test)


print('Classification report for test data is : \n',
      classification_report(y_test, test_rfc_pred))
# Out:
# Classification report for test data is :
#                precision    recall  f1-score   support
#
#            0       0.76      0.77      0.77       213
#            1       0.82      0.81      0.81       267
#
#     accuracy                           0.79       480
#    macro avg       0.79      0.79      0.79       480
# weighted avg       0.79      0.79      0.79       480

# %%
roc_auc = roc_auc_score(y_test, grid_search.predict_proba(x_test)[:,1])
print('Aera under ROC cure :',roc_auc)
# Out:
# Aera under ROC cure : 0.8766682491955478

# %% [markdown]
# * Roc: area under the curve tells us that among all predicted values according to our classes 87% are getting correctly predicted.

# %%
FPR_rfc_test, TPR_rfc_test, Thresholds_test = roc_curve(y_test, grid_search.predict_proba(x_test)[:,1])
plt.figure(figsize = (20,8))
plt.plot(FPR_rfc_test, TPR_rfc_test,   label = 'Test AUR Curve')
# Plot Base Rate ROC
plt.plot([0,1], [0,1], label = 'Base Rate')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize = 20)
plt.ylabel('True Positive Rate',  fontsize = 20)
plt.title('ROC Graph', fontsize = 20)
plt.legend(loc = "lower right")
plt.show()

# %% [markdown]
# # Feature importance

# %%
importance = grid_search.best_estimator_.feature_importances_
feature_imp = pd.Series(importance, index = wine.columns[:11]).sort_values(ascending = False)
feature_imp
plt.figure(figsize = (15, 8))
# Visualize the Importance Creating a bar plot
sns.barplot(x = feature_imp, y = feature_imp.index)
# Add labels to your graph
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features")
plt.show()

# %% [markdown]
# * among all 11 features important features we can select are alcohol sulphates, volatile acidity, total sulfur dioxide, density.

# %% [markdown]
# # Deployment

# %%
import pickle
pickle.dump(grid_search, open('wine_rf.pkl','wb'))

model = pickle.load(open('wine_rf.pkl','rb'))
